# %%
#pip install streamlit

# %%
import joblib
import pandas as pd
import numpy as np

# Load model
model = joblib.load("../models/final_rf_model-copy1.pkl")

# %%
def predict_intrusion(input_df):
    prediction = model.predict(input_df)
    result = ["Attack" if p == 0 else "Normal" for p in prediction]
    return result

# %%
# Load sample schema
sample_input = pd.read_csv("../data/X_val.csv")
sample_input.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.110249 -2.468724 -0.992663  0.751111 -0.007586 -0.004919 -0.014089
# 1 -0.110249 -0.124706 -0.442083  0.751111 -0.007725 -0.004821 -0.014089
# 2 -0.110249 -0.124706 -0.442083  0.751111 -0.007726 -0.004851 -0.014089
# 3 -0.110249 -0.124706  1.087305 -0.736235 -0.007762 -0.004919 -0.014089
# 4 -0.110249 -0.124706 -1.665594 -0.736235 -0.007762 -0.004919 -0.014089
#
#           7         8         9  ...        32        33        34        35  \
# 0 -0.089486 -0.007736 -0.095076  ...  0.391564  0.219977 -0.333214  1.526302
# 1 -0.089486 -0.007736 -0.095076  ...  1.258754  1.066401 -0.439078 -0.480197
# 2 -0.089486 -0.007736 -0.095076  ...  1.258754  1.066401 -0.439078 -0.027116
# 3 -0.089486 -0.007736 -0.095076  ... -0.936322 -1.049659 -0.121485 -0.480197
# 4 -0.089486 -0.007736 -0.095076  ... -1.026654 -1.138756 -0.121485 -0.480197
#
#          36        37        38        39        40        41
# ...

# %%
#Save Schema CSV (For Uploading in Web UI)
sample_input.head(1).to_csv("sample_input_schema.csv", index=False)
